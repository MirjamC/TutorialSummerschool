# %% [markdown]
# # Natural Language Processing

# %% [markdown]
# Start met laden van de packages en onze zojuist gemaakte dataset

# %%
import pandas as pd

# %%
data = pd.read_csv('data/fiets.csv', index_col =0)

# %%
data.head(2)
# Out:
#        Unnamed: 0.1  Unnamed: 0  \
# 33663         84265         108
# 33674         84276         121
#
#                                               identifier     type  \
# 33663  http://resolver.kb.nl/resolve?urn=MMKB23:00140...  artikel
# 33674  http://resolver.kb.nl/resolve?urn=ddd:01026592...  artikel
#
#                                       title                 date  \
# 33663       BUITENLAND. POLITIEK OVERZICHT.  1880/05/26 00:00:00
# 33674  Amsterdam, 31 Mei. Een Laatste Hoop.  1882/06/01 00:00:00
#
#                                                  content subcategory category  \
# 33663  ’s Gravenhage, 25 Mei.’t Is te Berlijn een lie...       fiets    fiets
# 33674  Ofschoon de meeste pruisische dioden n" weder'...       fiets    fiets
#
#        Year   DL score  Length    spatial
# 33663  1880  71.212121     792  Landelijk
# 33674  1882  71.364047    1107  Landelijk

# %% [markdown]
# ## Count word frequencies

# %% [markdown]
# Als eerste, meeste simpele stap van tekst analyse, kunnen we kijken naar de meest voorkomende woorden in de artikelen. Onderstaande functie is geschreven om dit te doen. Maar als eerste stap moeten we de artikelen van de kolom 'content' omzetten naar een lijst met woorden per artikel.

# %%
data['content list'] = data.content.apply(lambda x: x.lower().split())

# %%
def word_counter(dataframe_column):
    full_list = []
    for elemnt in dataframe_column:
        full_list += elemnt
    
    values_count = pd.Series(full_list).value_counts()
    return values_count

# %% [markdown]
# We kunnen de functie uitproberen:

# %%
values_count = word_counter(data['content list'])

# %%
values_count
# Out:
# de                  20041
# van                 12865
# het                 10233
# en                   9962
# een                  8878
#                     ...
# overwicht               1
# regeeren                1
# ondergeschikte          1
# veldtocht,              1
# noordzee-kanaal.        1
# Length: 62559, dtype: int64

# %% [markdown]
# Zoals je ziet zijn de eerste woorden allemaal woorden die inhoudelijk niet veel zeggen over de artikelen. Deze woorden, die veel voorkomen in onze taal maar inhoudelijk weinig zinnigs zeggen, noemen we stopwoorden. We kunnen een stopwoordenlijst gebruiken om deze woorden weg te filteren.

# %%
with open('data/stopwords-nl.txt', 'r') as f:
    stopwords = f.read().split("\n")

# %%
## Don't alter
def word_counter_stopword(dataframe_column):
    full_list = []
    for elemnt in dataframe_column:
        full_list += elemnt
        
    full_list = [i for i in full_list if i not in stopwords]
    
    values_count = pd.Series(full_list).value_counts()
    return values_count

# %%
values_count = word_counter_stopword(data['content list'])

# %%
values_count.head(10)
# Out:
# —         1437
# heer       883
# dagen      528
# plaats     436
# groote     433
# tijd       394
# geheel     351
# jaar       332
# man        326
# f          305
# dtype: int64

# %% [markdown]
# # Spacy

# %% [markdown]
# Naast een naieve worcount, zijn er ook andere opties mogelijk. Voor het vervolg van deze workshop gaan we gebruik maken van de Spacy package, die gebruikt wordt voor Natural language processing.

# %%
import spacy
from spacy import displacy
from collections import Counter

# %%
nlp = spacy.load("nl_core_news_sm")

# %%
data = data.dropna(subset=['content'])

# %%
def process_text(text):
    return nlp(text)

def flatten(xss):
    return [x for xs in xss for x in xs]

# %%
## deze code als comment omdat het lang duurt om te draaien
data["doc"] = data["content"].apply(process_text)

# %%
## Deze code ook als comment om te laten zien hoe je het model kan opslaan
import pickle

with open('data/fiets_nlp.pkl', 'wb') as f:
    pickle.dump(data, f)

# %%
with open('data/fiets_nlp.pkl', 'rb') as f:
    fiets_nlp = pickle.load(f)

# %%
fiets_nlp.head(2)
# Out:
#        Unnamed: 0.1  Unnamed: 0  \
# 33663         84265         108
# 33674         84276         121
#
#                                               identifier     type  \
# 33663  http://resolver.kb.nl/resolve?urn=MMKB23:00140...  artikel
# 33674  http://resolver.kb.nl/resolve?urn=ddd:01026592...  artikel
#
#                                       title                 date  \
# 33663       BUITENLAND. POLITIEK OVERZICHT.  1880/05/26 00:00:00
# 33674  Amsterdam, 31 Mei. Een Laatste Hoop.  1882/06/01 00:00:00
#
#                                                  content subcategory category  \
# 33663  ’s Gravenhage, 25 Mei.’t Is te Berlijn een lie...       fiets    fiets
# 33674  Ofschoon de meeste pruisische dioden n" weder'...       fiets    fiets
#
#        Year   DL score  Length    spatial  \
# 33663  1880  71.212121     792  Landelijk
# 33674  1882  71.364047    1107  Landelijk
#
#                                             content list  \
# 33663  [’s, gravenhage,, 25, mei.’t, is, te, berlijn,...
# 33674  [ofschoon, de, meeste, pruisische, dioden, n",...
#
#                                                      doc
# 33663  (’s, Gravenhage, ,, 25, Mei.’t, Is, te, Berlij...
# 33674  (Ofschoon, de, meeste, pruisische, dioden, n, ...

# %% [markdown]
# # Named Entity Recognition

# %% [markdown]
# Spacy slaat informatie over de gevonden named entities op in het doc item. Deze informatie staat opgeslagen in de kolom 'doc' en kan daar ook uitgehaald worden.
#
# Spacy kent de volgende Named entities:

# %% [markdown]
# * PERSON:      People, including fictional.
# * NORP:        Nationalities or religious or political groups.
# * FAC:         Buildings, airports, highways, bridges, etc.
# * ORG:         Companies, agencies, institutions, etc.
# * GPE:         Countries, cities, states.
# * LOC:         Non-GPE locations, mountain ranges, bodies of water.
# * PRODUCT:     Objects, vehicles, foods, etc. (Not services.)
# * EVENT:       Named hurricanes, battles, wars, sports events, etc.
# * WORK_OF_ART: Titles of books, songs, etc.
# * LAW:         Named documents made into laws.
# * LANGUAGE:    Any named language.
# * DATE:        Absolute or relative dates or periods.
# * TIME:        Times smaller than a day.
# * PERCENT:     Percentage, including ”%“.
# * MONEY:       Monetary values, including unit.
# * QUANTITY:    Measurements, as of weight or distance.
# * ORDINAL:     “first”, “second”, etc.
# * CARDINAL:    Numerals that do not fall under another type.

# %% [markdown]
# Je kan ook de spacy module vragen voor uitleg over een bepaalde Named Entity:

# %%
spacy.explain('GPE')
# Out:
# 'Countries, cities, states'

# %% [markdown]
# Je kan per artikel de gevonden Named Entities tonen. Deze worden dan met verschillende kleuren weergegeven.

# %%
doc = fiets_nlp['doc'].to_list()[2]

# %%
displacy.serve(doc, style = "ent")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="nl">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">Men is er in ons dierbaar Vaderland eenmaal gewoon aan geraakt, om te hooren klagen over ons verdedigingsvermogen, en menigeen zal, oppervlakkig oordeelende, in den waan Verkeeren, dat bij onze naburen alles in dit opzicht «couleur de rosé&quot; is, toch zouden zij, die aldus oordcelen, bij nader inïien, wel een» tot een ander besluit gebracht kunnen worden o. a. door den blik naar
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     België
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  te wenden. Soms wordt wel eens beweerd, dat van
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     liberale
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  kabinetten Fiets goeds te wachten is voor de defensie, terwijl daaruit dan ïou moeten voortvloeien, dat slechts onder een conservatieve regeering de vaderlandsliefde zoo ver gaat, om geld en bloed ten offer te willen brengen, voor de verdediging des lands. Kan men dezen stelregel aannemen, dan zou zoowel in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Holland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  als in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     België
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  op dit oogenblik de militaire quaestie op afdosnde wijze beslist moeten wezen, hetgeen wij intusschen maar al te goed weten, dat niet het geval is. In
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     België
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is men oülangs weder eens wakker geschud, en het kan wellicht geen kwaad, om dat incident in herinnering te brengen, waartoe wij ons in 's lands vergaderzaal te
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brus■
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# el hebben te verplaatsen, en wel omtrent het tijdstip van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     24 Juni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . Toen werd namelijk een wetsontwerp behandeld, waarbij gelden worden aangevraagd:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# &quot; voor den aankoop van
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pionniersgereedschap
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ten behoeve der infanterie, waarvoor een nieuw model was vastgesteld geworden, begrooting fr.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# * tot verhooging der belegerings affuiten van
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  en
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cm. hegrooting fr.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     782,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# * tot voortzetting van de verbete*ing der rerdedigingsmiddelen aan de
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beneden-Schelde
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , meer bepaald de voltooiing van het fort
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     St. Philippe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , en aanleg eener gepantserde batterij bij het fort
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     St. Marie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  en van een losplaats bij het fort la
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Perle
#     <span style="font-size: 0.8em; font-weight: bold; li
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
# 127.0.0.1 - - [23/Jun/2025 22:16:07] "GET / HTTP/1.1" 200 37608
# Shutting down server on port 5000.

# %%
## Zelf doen: Bekijk een random andere regel

# %% [markdown]
# Bekijk het op: http://localhost:5000/

# %% [markdown]
# Naast de named entities op deze manier tonen, kun je er ook verdere analyses mee doen. Je kan ze bijvoorbeeld per category opslaan als losse kolommen in je dataframe

# %% [markdown]
# Hieronder staat een functie waarmee je Named entities van een bepaalde soort uit het doc item kan halen. Deze worden vervolgens als een lijst opgeslagen in een nieuwe kolom in het dataframe.

# %%
def get_gpe(doc, entity):
    return [ent.text for ent in doc.ents if ent.label_ == entity]

# %% [markdown]
# Vervolgens kun je deze functie gebruiken op je dataframe.
# Deze functie heeft als input de doc item van het dataframe, en de gekozen named entity.
#
# In onderstaande voorbeeld wordt de categroy GPE eruit gehaald.

# %%
fiets_nlp['GPE'] = fiets_nlp['doc'].apply(lambda x: get_gpe(x, 'GPE'))

# %% [markdown]
# Vervolgens kun je deze kolom weer gebruiken om de meest voorkomende GPE eruit te halen.

# %%
values_count = word_counter(fiets_nlp['GPE'])

# %%
values_count.head(10)
# Out:
# Parijs       282
# Amsterdam    186
# Londen       163
# Frankrijk    163
# Engeland     161
# Berlijn       89
# Utrecht       83
# Amerika       79
# Nederland     78
# Brussel       71
# dtype: int64

# %%
## Zelf doen
## Maak kolommen aan voor de entities ......

# %% [markdown]
# Nu je een aantal Named Entities hebt, kun je de datatset weer in twee splitsen (regionaal en landelijk) en kijken of detop 10 meest voorkomende woorden overeen komen.

# %%
regionaal = fiets_nlp[fiets_nlp['spatial'] == 'Regionaal/lokaal']

# %%
## Zelf doen
landelijk = fiets_nlp[fiets_nlp['spatial'] == 'Landelijk']

# %%
values_count = word_counter(regionaal['GPE'])
values_count.head(10)
# Out:
# Parijs       244
# Amsterdam    161
# Frankrijk    136
# Londen       136
# Engeland     134
# Berlijn       74
# Utrecht       73
# Amerika       73
# Nederland     65
# Europa        61
# dtype: int64

# %%
values_count = word_counter(landelijk['GPE'])
values_count.head(10)
# Out:
# Parijs       38
# Londen       27
# Engeland     27
# Frankrijk    27
# Amsterdam    25
# Brussel      17
# Berlijn      15
# Nederland    13
# België       12
# Weenen       10
# dtype: int64

# %%
## Zelf doen: andere kolommen word count vergelijken

# %% [markdown]
# # Part of speech tagging

# %% [markdown]
# Uitleg part of speech tagging en wat het inhoud

# %%
doc = fiets_nlp['doc'].to_list()[2]

# %%
displacy.serve(doc, style = "dep")
# Out:
# C:\Users\mirjam\anaconda3\lib\site-packages\spacy\displacy\__init__.py:106: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="nl">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="nl" id="c9e63155c34048cd9d82ccadba7b23f6-0" class="displacy" width="258700" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Men</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">er</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">ons</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">dierbaar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Vaderland</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">eenmaal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">gewoon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">aan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">geraakt,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">om</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">te</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">hooren</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">klagen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">ons</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">verdedigingsvermogen,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">menigeen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">zal,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">oppervlakkig</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">oordeelende,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">den</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">waan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">Verkeeren,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">dat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">bij</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle"
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
# 127.0.0.1 - - [23/Jun/2025 22:33:26] "GET / HTTP/1.1" 200 1225026
# Shutting down server on port 5000.

# %% [markdown]
# Bekijk het op: http://localhost:5000/

# %% [markdown]
# Ook voor part of speech tagging kun je kolommen maken in je dataframe met categorieën.
# Hiervoor is onderstaande functie geschreven:

# %%
def get_pos(doc, pos_tag):
    return [token for token in doc if token.pos_ == pos_tag]

# %% [markdown]
# Bij de Naed entities hebben we de top 10 meest voorkomende entities per categorie vergeleken tussen regionaal en lokaal. Voor de Part of Speech tagging gaan we kijken hoeveel procent van een artikel uit bepaalde woordsoorten bestaat. Hiervoor berekenen we eerst het aantal voorkomens per woordsoort, en daarna delen we dit door de lengte van het artikel. We gebruiken hiervoor het totale dataframe.

# %% [markdown]
# Hieronder laten we deze methode zien in 3 stappen, voor zelfstandige naamwoorden (nouns)

# %% [markdown]
# Stap 1:

# %%
fiets_nlp['noun'] = fiets_nlp['doc'].apply(lambda x: get_pos(x, 'NOUN'))

# %% [markdown]
# Stap 2:

# %%
fiets_nlp['noun_count'] = fiets_nlp['noun'].apply(lambda x: len(x))

# %% [markdown]
# Stap 3:

# %%
fiets_nlp['noun_perc'] = (fiets_nlp['noun_count'] / fiets_nlp['Length']) * 100

# %%
fiets_nlp.head(2)
# Out:
#        Unnamed: 0.1  Unnamed: 0  \
# 33663         84265         108
# 33674         84276         121
#
#                                               identifier     type  \
# 33663  http://resolver.kb.nl/resolve?urn=MMKB23:00140...  artikel
# 33674  http://resolver.kb.nl/resolve?urn=ddd:01026592...  artikel
#
#                                       title                 date  \
# 33663       BUITENLAND. POLITIEK OVERZICHT.  1880/05/26 00:00:00
# 33674  Amsterdam, 31 Mei. Een Laatste Hoop.  1882/06/01 00:00:00
#
#                                                  content subcategory category  \
# 33663  ’s Gravenhage, 25 Mei.’t Is te Berlijn een lie...       fiets    fiets
# 33674  Ofschoon de meeste pruisische dioden n" weder'...       fiets    fiets
#
#        Year   DL score  Length    spatial  \
# 33663  1880  71.212121     792  Landelijk
# 33674  1882  71.364047    1107  Landelijk
#
#                                             content list  \
# 33663  [’s, gravenhage,, 25, mei.’t, is, te, berlijn,...
# 33674  [ofschoon, de, meeste, pruisische, dioden, n",...
#
#                                                      doc  \
# 33663  (’s, Gravenhage, ,, 25, Mei.’t, Is, te, Berlij...
# 33674  (Ofschoon, de, meeste, pruisische, dioden, n, ...
#
#                                                      GPE  \
# 33663  [Berlijn, Rome, Rome, nagaat, Granlle, Berlijn...
# 33674  [Landdag, TaS, Pruisen, niag, Bismarck, Nergen...
#
#                                                     noun  noun_count  \
# 33663  [Mei.’t, verwarring, wetsontwerp, overweging, ...         153
# 33674  [dioden, medewerking, bisschop, vrede, tussche...         218
#
#        noun_perc
# 33663  19.318182
# 33674  19.692864

# %%
columns = ['noun_perc']

# %%
fiets_nlp.groupby(['spatial'])[columns].mean()
# Out:
#                   noun_perc
# spatial
# Landelijk         20.788330
# Regionaal/lokaal  20.131937

# %%
fiets_nlp.groupby(['spatial'])[columns].median()
# Out:
#                   noun_perc
# spatial
# Landelijk         20.693037
# Regionaal/lokaal  20.164609
